# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("hypertension_dataset.csv")

# %%
dataset
# Out:
#       Age  Salt_Intake  Stress_Score       BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           Normal             6.4  25.8
# 1      32         11.7            10           Normal             5.4  23.4
# 2      78          9.5             3           Normal             7.1  18.7
# 3      38         10.0            10     Hypertension             4.2  22.1
# 4      41          9.8             1  Prehypertension             5.8  16.2
# ...   ...          ...           ...              ...             ...   ...
# 1980   56         10.2             0           Normal             6.5  25.0
# 1981   29          8.9             4     Hypertension             6.9  16.9
# 1982   64          5.9             9           Normal             5.6  18.9
# 1983   35          7.4             8  Prehypertension             8.2  29.2
# 1984   38          7.3             0           Normal             8.3  18.6
#
# ...

# %%
print(dataset.Age.size)
# Out:
# 1985

# %%
dataset.columns
# Out:
# Index(['Age', 'Salt_Intake', 'Stress_Score', 'BP_History', 'Sleep_Duration',
#        'BMI', 'Medication', 'Family_History', 'Exercise_Level',
#        'Smoking_Status', 'Has_Hypertension'],
#       dtype='object')

# %%
x=dataset.drop("Has_Hypertension",axis=1)
print(x)
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           1             4.2  22.1
# 4      41          9.8             1           2             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           1             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           2             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History  Exercise_Level  Smoking_Status
# ...

# %%
y=dataset.Has_Hypertension
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1980    0
# 1981    0
# 1982    0
# 1983    1
# 1984    1
# Name: Has_Hypertension, Length: 1985, dtype: int64

# %%
print(dataset['BP_History'].unique())
# Out:
# ['Normal' 'Hypertension' 'Prehypertension']

# %%
print(dataset['Exercise_Level'].unique())
# Out:
# ['Low' 'Moderate' 'High']

# %%
print(dataset["Smoking_Status"].unique())
# Out:
# ['Non-Smoker' 'Smoker']

# %%
print(dataset["Medication"].unique())
# Out:
# [nan 'ACE Inhibitor' 'Other' 'Beta Blocker' 'Diuretic']

# %%
History=dataset["BP_History"]
dataset["BP_History"]=dataset["BP_History"].map({
   "Normal":0,
   "Hypertension":1,
   "Prehypertension":2
}).astype(int)

# %%
dataset["Exercise_Level"]=dataset["Exercise_Level"].map({
    "Low":0,
    "Moderate":1,
    "High":2
}).astype(int)

# %%
dataset["Smoking_Status"]=dataset["Smoking_Status"].map({
    "Non-Smoker":0,
    "Smoker":1
}).astype(int)

# %%
x.columns[x.isna().any()]
# Out:
# Index(['Medication'], dtype='object')

# %%
dataset["Medication"] = dataset["Medication"].fillna("NO PROBELM")

# %%
dataset["Medication"] = dataset["Medication"].map({
    "NO PROBELM":0,
    "ACE Inhibitor":1,
    "Other":2,
    "Beta Blocker":3,
    "Diuretic":4
}).astype(int)

# %%
dataset
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           1             4.2  22.1
# 4      41          9.8             1           2             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           1             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           2             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication Family_History  Exercise_Level  Smoking_Status  \
# ...

# %%
dataset["Family_History"] = dataset["Family_History"].map({
   "Yes":1,
   "No":2
}).astype(int)

# %%
dataset["Has_Hypertension"]=dataset["Has_Hypertension"].map({


      "Yes":0,
      "No":1
}).astype(int)

# %%
dataset
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           1             4.2  22.1
# 4      41          9.8             1           2             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           1             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           2             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History  Exercise_Level  Smoking_Status  \
# ...

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuarcy:{0}%".format(accuracy_score(y_test,y_pred)*100))
# Out:
# Accuarcy:95.97585513078471%

# %%
sns.relplot(data=dataset,kind="scatter",x="Sleep_Duration",y="Age",col="Stress_Score",row="Smoking_Status")

# %%
index=48
y_pred=model.predict(x_test.iloc[[index]].values)
if y_pred==1:
  print("not affect to hypertention")
else:
  print("affect to hypertention")
# Out:
# not affect to hypertention
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
